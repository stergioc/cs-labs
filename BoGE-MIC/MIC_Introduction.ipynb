# %% [markdown]
# <table>
# <tr height="150px">
# <th>
# <img height="150px" src='https://stergioc.github.io/assets/img/logos.png' />
# </th>
# </tr>
# </table>
#
# <h1>Medical Image Computing - Introduction</h1>
# <h3>Stergios CHRISTODOULIDIS (CentraleSupélec)</h3>
#
# [![MIC-Tutorial](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/stergioc/cs-labs/blob/main/BoGE-MIC/MIC-Introduction.ipynb)

# %% [markdown]
# ## Downloading example data
#
# The example data for this session are taken from TCIA: MR Imaging and Segmentations with Matched Brain Biopsy Pathology Slides from Patients with Brain Metastases from Primary Lung Cancer
#
# DOI: [10.7937/k0sm-y874](http://doi.org/10.7937/k0sm-y874)

# %%
# %%capture
# !wget -O YG_985XO5NHL516_flair.nii.gz https://nextcloud.centralesupelec.fr/public.php/dav/files/NtDDeNAiB5K5Lni
# !wget -O YG_985XO5NHL516_whole_seg.nii.gz https://nextcloud.centralesupelec.fr/public.php/dav/files/eaA6gNK5C22kNzN
# !wget -O YG_985XO5NHL516_wsi.svs https://nextcloud.centralesupelec.fr/public.php/dav/files/RxGgeLN4DLWsi2C

# %% [markdown]
# ## Installing library for WSIs Processing

# %%
# %%capture
# !pip install openslide-python openslide-bin

# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import nibabel as nib
import openslide

# %% [markdown]
# ## Load MRI and WSI
#
# Using the two libraries (nibabel and openslide) load the images and visualize them.
#
# Use the `nib.load` and `openslide.OpenSlide` functions. You can take a look at their corresponding documentation:
# - https://nipy.org/nibabel/nibabel_images.html
# - https://openslide.org/api/python/#module-openslide

# %%
# Your code here:
flair_img = # ...
flair_seg = # ...
wsi = # ...

# %% [markdown]
# ## Print the sizes of the imported images
#
# - What is the size of the MRI and WSI images?

# %%
# Your code here:
# Print the shapes/dimensions of the images you loaded
# ...

# %% [markdown]
# ## Print the metadata of the MRI image and the WSI
#
# Refer to the documentation to determine exactly where the metadata is stored and how to access it.
#
# - What is the volume of a voxel in this MRI? (hint: use `.get_zooms()` function)
# - How many downsampled versions of the WSI are available in the `.svs` file? (hint: `level_downsamples`)
# - What is the largest magnification available? (hint: `objective-power`)

# %%
# Your code here:
# ....

# %% [markdown]
# ## Plot the Images
#
# Get the data from the files and plot the MRI images and the WSI data.
#
# - How can we plot the images given their size?
#
# 1. Plot a specific slice for the MRI image together with the corresponding segmentation map that is provided in the `_seg.nii.gz` file (hint: use the `plt.imshow()` function).
#
# 2. Plot a small region of the WSI of size `(512,512)` at `20x` magnification in which you can see cells in detail. (hint: use the `read_region()` function)

# %%
# Your code here:
# ...
